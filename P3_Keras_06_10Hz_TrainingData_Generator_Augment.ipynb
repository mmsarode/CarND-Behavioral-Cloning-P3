# %% [markdown]
# # Traffic Sign Classification with Keras
#
# Keras exists to make coding deep neural networks simpler. To demonstrate just how easy it is, you’re going to use Keras to build a convolutional neural network in a few dozen lines of code.
#
# You’ll be connecting the concepts from the previous lessons to the methods that Keras provides.

# %% [markdown]
# ## Dataset
#
# The network you'll build with Keras is similar to the example in Keras’s GitHub repository that builds out a [convolutional neural network for MNIST](https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py).
#
# However, instead of using the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, you're going to use the [German Traffic Sign Recognition Benchmark](http://benchmark.ini.rub.de/?section=gtsrb&subsection=news) dataset that you've used previously.
#
# You can download pickle files with sanitized traffic sign data here:

# %%
import numpy as np
import pandas as pd

fileloc = 'Center_Lap_01/'
fileloc2 = 'Off_Track_02/'
csvfilename = fileloc + 'driving_log.csv'
csvfilename2 = fileloc2 + 'driving_log.csv'
hd = ['center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed']
df1 = pd.read_csv(csvfilename, names = hd)
print(df1['center'][1][70:])
df2 = pd.read_csv(csvfilename2, names = hd)
print(df2['center'][1][70:])

# print(df2[0])



df = df1.append(df2, ignore_index=True)

# numpy_array = df.as_matrix()
original_headers = list(df.columns.values)
print(original_headers)


print(df['center'][2][70:])

print(df['steering'][1298])
print(df['steering'][1:10])
# print(df['steering'][8035])
print(df['center'][0:3])

print(df.shape)
print(df2.shape)
# Out:
# Center_Lap_01/IMG/center_2017_02_22_19_53_05_041.jpg
# Off_Track_02/IMG/center_2017_02_22_20_09_02_131.jpg
# ['center', 'left', 'right', 'steering', 'throttle', 'brake', 'speed']
# Center_Lap_01/IMG/center_2017_02_22_19_53_05_107.jpg
# -0.4
# 1    0.00
# 2    0.00
# 3    0.00
# 4    0.00
# 5    0.00
# 6    0.00
# 7    0.00
# 8    0.00
# 9   -0.05
# Name: steering, dtype: float64
# 0    /home/mahesh/udacity/CarND-Behavioral-Cloning-...
# 1    /home/mahesh/udacity/CarND-Behavioral-Cloning-...
# 2    /home/mahesh/udacity/CarND-Behavioral-Cloning-...
# Name: center, dtype: object
# (8653, 7)
# (2086, 7)

# %%
print(df['center'][80])
# Out:
# /home/mahesh/udacity/CarND-Behavioral-Cloning-P3/beta_simulator_linux/Center_Lap_01/IMG/center_2017_02_22_19_53_11_210.jpg

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
imnum = [10, 13, 19]

fname = [df['center'][i][70:] for i in imnum]
# fname2 = [df2['center'][i][70:] for i in imnum]




# im1 = cv2.imread(filename1)[::1]
im = [cv2.imread(f)[...,::-1] for f in fname]



im_crop = np.array([image[60:140,:] for image in im])

print(type(im[0]))
print(im[0].shape)
# plt.figure(figsize=(1,1))
plt.imshow(im[0])
# Out:
# <class 'numpy.ndarray'>
# (160, 320, 3)

# %% [markdown]
# ## Resize

# %%
new_size = (32,32)

im_resized = np.array([cv2.resize(image, (50,50)) for image in im_crop])#, fx=0.25, fy=0.5) 

X_traindemo = im_resized
y_traindemo = np.array([df['steering'][i] for i in imnum])
# plt.figure(figsize=(1,1))
plt.imshow(im_resized[0])
print('X train size: ', X_traindemo.shape)

print('y train size: ', y_traindemo.shape)
print(y_traindemo)
# Out:
# X train size:  (3, 50, 50, 3)
# y train size:  (3,)
# [-0.25      -0.8500001 -0.05     ]

# %% [markdown]
# ## Overview
#
# Here are the steps you'll take to build the network:
#
# 1. Load the training data.
# 2. Preprocess the data.
# 3. Build a feedforward neural network to classify traffic signs.
# 4. Build a convolutional neural network to classify traffic signs.
# 5. Evaluate the final neural network on testing data.
#
# Keep an eye on the network’s accuracy over time. Once the accuracy reaches the 98% range, you can be confident that you’ve built and trained an effective model.

# %%
# import numpy as np
import math

# Fix error with TF and Keras
import tensorflow as tf
tf.python.control_flow_ops = tf

print('Modules loaded.')
# Out:
# Modules loaded.

# %% [markdown]
# ## Load the Data
#
# Start by importing the data from the pickle file.

# %%
from sklearn.utils import shuffle
imnum = range(int(df.shape[0]))
print(max(imnum))

fname = [df['center'][i][70:] for i in imnum]


fname_left= [df['left'][i][70:] for i in imnum]

fname_right= [df['right'][i][70:] for i in imnum]



# im1 = cv2.imread(filename1)[::1]
# im = [cv2.imread(f)[...,::-1] for f in fname]


# X_train = image_preprocess([cv2.imread(f)[...,::-1] for f in fname])
X_train = np.array(([cv2.imread(f)[...,::-1] for f in fname]))
y_train = np.array([df['steering'][i] for i in imnum])

# X_train2 = [np.fliplr(image) for image in X_train]
# y_train2 = -1*y_train

# X_train = np.concatenate([X_train2, X_train])
# y_train = np.concatenate([y_train2, y_train])


for i in range(2):
    X_train, y_train = shuffle(X_train, y_train)
    
print(X_train.shape)
print(y_train.shape)
# print(y_train)
# Out:
# 8652
# (8653, 160, 320, 3)
# (8653,)

# %%
import cv2

def brightness(image):
    rand_beta = .7 + np.random.uniform(0, 0.6)
    
    image1 = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
    image1 = np.array(image1, dtype = np.float64)
    
    image1[:, :, 2] = image1[:, :, 2]*rand_beta
    
   
    image1[:,:,2][image1[:,:,2]>255]  = 255
    
    image1 = image1.astype('B') 

    image1 = cv2.cvtColor(image1, cv2.COLOR_HSV2RGB)
    
    return image1

def translate_data(image, maxtransx, maxtransy):
    
    nrow = image.shape[0]
    ncol = image.shape[1]

    
    
#   Translation in x and y direction by number of pixels 
    tr_x =  np.random.randint(maxtransx) - maxtransx/2
    tr_y =  np.random.randint(maxtransy) - maxtransy/2  

    

   
    
    Trans_matrix = np.array([[1,0,tr_x],[0,1,tr_y]])   
    
    image_new = cv2.warpAffine(image, Trans_matrix,(ncol, nrow))

#   Convert float 64 to uint8 to save memory
    image_new = image_new.astype('B') 
    return image_new

plt.imshow(translate_data(X_train[11], 80, 10))

plt.figure()
plt.imshow(brightness(X_train[11]))

# %% [markdown]
# ## Generator & data augmentation

# %%
# i = 0
# def generate_data(X_train, y_train, batchsize):
#     istart = 0
#     batchsize = len(y_train)//(len(y_train)//batchsize)
#     while True:
        
#         iend = istart + batchsize
#         istart = iend
#         yield (X_train[istart:iend], y_train[istart:iend])

def generate_data(batchsize):

    while True:
        for i in range(len(y_train)//batchsize+1):
            
            
            print("Number of batchstart:", i)

            yield X_train[i*batchsize:(i+1)*batchsize], y_train[i*batchsize:(i+1)*batchsize]

a = generate_data(2)

# %%
print(next(a)[0][0][0])
# Out:
# Number of batchstart: 3
# [[124 153 195]
#  [124 153 195]
#  [123 152 194]
#  [123 152 194]
#  [123 152 194]
#  [122 151 193]
#  [122 151 193]
#  [122 151 193]
#  [122 151 193]
#  [122 151 193]
#  [121 150 192]
#  [121 150 192]
#  [121 150 192]
#  [120 149 191]
#  [120 149 191]
#  [120 149 191]
#  [120 149 191]
#  [120 149 191]
#  [119 148 190]
#  [119 148 190]
#  [119 148 190]
#  [118 147 189]
#  [118 147 189]
#  [118 147 189]
#  [117 146 188]
#  [117 146 188]
#  [116 145 187]
#  [116 145 187]
#  [116 145 187]
#  [115 144 186]
#  [115 144 186]
#  [115 144 186]
#  [114 143 185]
#  [114 143 185]
#  [113 142 184]
#  [113 142 184]
#  [113 142 184]
#  [112 141 183]
#  [112 141 183]
#  [112 141 183]
#  [112 141 183]
#  [112 141 183]
#  [111 140 182]
#  [111 140 182]
#  [111 140 182]
#  [110 139 181]
#  [110 139 181]
#  [110 139 181]
#  [110 138 178]
#  [110 138 178]
#  [109 137 177]
#  [109 137 177]
#  [109 137 177]
#  [108 136 176]
#  [108 136 176]
#  [108 136 176]
#  [109 137 177]
#  [109 137 177]
#  [108 136 176]
#  [108 136 176]
#  [108 136 176]
#  [107 135 175]
#  [107 135 175]
#  [107 135 175]
#  [107 135 175]
#  [107 135 175]
#  [106 134 174]
#  [106 134 174]
#  [106 134 174]
#  [105 133 173]
#  [105 133 173]
#  [105 133 173]
#  [104 132 172]
#  [104 132 172]
#  [103 131 171]
#  [103 131 171]
#  [103 131 171]
#  [102 130 170]
#  [102 130 170]
#  [102 130 170]
#  [102 130 170]
#  [102 130 170]
#  [101 129 169]
#  [101 129 169]
#  [101 129 169]
#  [100 128 168]
#  [100 128 168]
#  [100 128 168]
#  [101 129 169]
#  [101 129 169]
#  [100 128 168]
#  [100 128 168]
#  [100 128 168]
#  [ 99 127 167]
#  [ 99 127 167]
#  [ 99 127 167]
#  [101 126 166]
#  [101 126 166]
#  [100 125 165]
#  [100 125 165]
#  [100 125 165]
#  [ 99 124 164]
#  [ 99 124 164]
#  [ 99 124 164]
#  [100 125 165]
#  [100 125 165]
#  [ 99 124 164]
#  [ 99 124 164]
#  [ 99 124 164]
#  [ 98 123 163]
#  [ 98 123 163]
#  [ 98 123 163]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 97 122 162]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 96 121 161]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 95 120 160]
#  [ 94 119 159]
#  [ 94 119 159]
#  [ 94 119 159]
#  [157 152 114]
#  [158 153 115]
#  [157 149 113]
#  [145 137 101]
#  [129 120  87]
#  [119 110  77]
#  [118 109  78]
#  [121 112  81]
#  [129 112  82]
#  [139 122  92]
#  [153 136 106]
#  [163 146 116]
#  [167 151 118]
#  [166 150 117]
#  [165 149 116]
#  [165 149 115]
#  [162 146 112]
#  [173 157 123]
#  [182 166 130]
#  [181 165 129]
#  [178 162 126]
#  [175 160 121]
#  [167 152 113]
#  [158 143 104]
#  [147 138 109]
#  [136 127  98]
#  [123 114  83]
#  [122 113  80]
#  [135 127  91]
#  [157 149 112]
#  [178 170 131]
#  [190 182 143]
#  [189 182 140]
#  [190 183 141]
#  [193 185 146]
#  [195 187 148]
#  [191 183 146]
#  [178 170 133]
#  [159 151 115]
#  [144 136 100]]

# %% [markdown]
# ## Train the Network
#
# 1. Compile the network using adam optimizer and categorical_crossentropy loss function.
# 2. Train the network for ten epochs and validate with 20% of the training data.

# %%
# TODO: Re-construct the network and add dropout after the pooling layer.
from keras.models import Sequential
from keras.layers import Dropout, Convolution2D, MaxPooling2D, Lambda, Cropping2D 
from keras.layers.core import Dense, Activation, Flatten

nb_filters = 20
pool_size = (2, 2)
# convolution kernel size
kernel_size = (3, 3)
input_shape = (160, 320,3)
pool_size = (2, 2)
# model.add(Convolution2D(nb_filters, kernel_size[0], kernel_size[1],
#                         border_mode='valid',
#                         input_shape=input_shape))
model = Sequential()
model.add(Cropping2D(cropping=((60, 20), (0, 0)), input_shape=input_shape))
model.add(Lambda(lambda x: -0.5 + x/255.0))

model.add(Convolution2D(nb_filters, 5, 5))
# model.add(MaxPooling2D(pool_size=pool_size))
          
model.add(Convolution2D(nb_filters, 5, 5))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.25))

model.add(Convolution2D(nb_filters, 3, 3))
model.add(Convolution2D(nb_filters, 3, 3))
model.add(MaxPooling2D(pool_size=pool_size))




model.add(Convolution2D(nb_filters, 3, 3))
model.add(MaxPooling2D(pool_size=pool_size))
          
model.add(Dropout(0.50))
model.add(Activation('relu'))
          
model.add(Flatten())
model.add(Dense(600))
model.add(Activation('relu'))
model.add(Dense(190))
model.add(Activation('relu'))
model.add(Dense(50))
model.add(Activation('relu'))
model.add(Dense(25))
model.add(Activation('relu'))
model.add(Dense(1))

# model.add(Activation('softmax'))
# Out:
# Using TensorFlow backend.

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (8653,)
# (8653, 160, 320, 3)

# %%
# model.compile('adam', 'categorical_crossentropy', ['accuracy'])
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mse'])
# history = model.fit(X_train, y_train, batch_size=128*2, nb_epoch=2, validation_split=0.25)
history = model.fit_generator(generate_data(128*2), samples_per_epoch = len(y_train), nb_epoch = 2)#, verbose=2, callbacks=[], validation_data=None, class_weight=None, nb_worker=1)
# Out:
# Number of batchstart:Epoch 1/2
# 0
# Number of batchstart: 1
# Number of batchstart: 2
# Number of batchstart: 3
# Number of batchstart: 4
# Number of batchstart: 5
# Number of batchstart: 6
# Number of batchstart: 7
# Number of batchstart: 8
# 6912/8653 [======================>.......] - ETA: 14s - loss: 0.0930 - mean_squared_error: 0.0483Number of batchstart: 3
# 7168/8653 [=======================>......] - ETA: 12s - loss: 0.0929 - mean_squared_error: 0.0484Number of batchstart: 4
# 7424/8653 [========================>.....] - ETA: 10s - loss: 0.0914 - mean_squared_error: 0.0475Number of batchstart: 5
# 7680/8653 [=========================>....] - ETA: 8s - loss: 0.0919 - mean_squared_error: 0.0479 Number of batchstart: 6
# 7936/8653 [==========================>...] - ETA: 5s - loss: 0.0919 - mean_squared_error: 0.0481Number of batchstart: 7
# 8192/8653 [===========================>..] - ETA: 3s - loss: 0.0912 - mean_squared_error: 0.0477Number of batchstart: 8
# 8448/8653 [============================>.] - ETA: 1s - loss: 0.0914 - mean_squared_error: 0.0481Number of batchstart: 9
# 8653/8653 [==============================] - 74s - loss: 0.0911 - mean_squared_error: 0.0479
# Epoch 2/2
# Number of batchstart: 10
#  256/8653 [..............................] - ETA: 58s - loss: 0.1118 - mean_squared_error: 0.0671Number of batchstart: 11
#  512/8653 [>.............................] - ETA: 57s - loss: 0.0932 - mean_squared_error: 0.0529Number of batchstart: 12
#  768/8653 [=>............................] - ETA: 55s - loss: 0.0914 - mean_squared_error: 0.0509Number of batchstart: 13
# 1024/8653 [==>...........................] - ETA: 53s - loss: 0.0947 - mean_squared_error: 0.0528Number of batchstart: 14
# 1280/8653 [===>..........................] - ETA: 51s - loss: 0.0945 - mean_squared_error: 0.0536Number of batchstart: 15
# 1536/8653 [====>.........................] - ETA: 49s - loss: 0.0917 - mean_squared_error: 0.0519Number of batchstart: 16
# 1792/8653 [=====>........................] - ETA: 48s - loss: 0.0912 - mean_squared_error: 0.0517Number of batchstart: 17
# 2048/8653 [======>.......................] - ETA: 46s - loss: 0.0891 - mean_squared_error: 0.0504Number of batchstart: 18
# 2304/8653 [======>.......................] - ETA: 44s - loss: 0.0900 - mean_squared_error: 0.0506Number of batchstart: 19
# 2560/8653 [=======>......................] - ETA: 42s - loss: 0.0892 - mean_squared_error: 0.0496Number of batchstart: 20
# 2816/8653 [========>.....................] - ETA: 41s - loss: 0.0901 - mean_squared_error: 0.0501Number of batchstart: 21
# 3072/8653 [=========>....................] - ETA: 39s - loss: 0.0906 - mean_squared_error: 0.0503Number of batchstart: 22
# 3328/8653 [==========>...................] - ETA: 37s - loss: 0.0891 - mean_squared_error: 0.0491Number of batchstart: 23
# 3584/8653 [===========>..................] - ETA: 35s - loss: 0.0889 - mean_squared_error: 0.0492Number of batchstart: 24
# 3840/8653 [============>.................] - ETA: 33s - loss: 0.0877 - mean_squared_error: 0.0481Number of batchstart: 25
# 4096/8653 [=============>................] - ETA: 32s - loss: 0.0884 - mean_squared_error: 0.0488Number of batchstart: 26
# 4352/8653 [==============>...............] - ETA: 30s - loss: 0.0885 - mean_squared_error: 0.0488Number of batchstart: 27
# 4608/8653 [==============>...............] - ETA: 28s - loss: 0.0898 - mean_squared_error: 0.0499Number of batchstart: 28
# 4864/8653 [===============>..............] - ETA: 26s - loss: 0.0894 - mean_squared_error: 0.0492Number of batchstart: 29
# 5120/8653 [================>.............] - ETA: 24s - loss: 0.0885 - mean_squared_error: 0.0487Number of batchstart: 30
# 5376/8653 [=================>............] - ETA: 23s - loss: 0.0893 - mean_squared_error: 0.0494Number of batchstart: 31
# 5632/8653 [==================>...........] - ETA: 21s - loss: 0.0894 - mean_squared_error: 0.0492Number of batchstart: 32
# 5888/8653 [===================>..........] - ETA: 19s - loss: 0.0884 - mean_squared_error: 0.0486Number of batchstart: 33
# 6144/8653 [====================>.........] - ETA: 17s - loss: 0.0878 - mean_squared_error: 0.0479Number of batchstart: 0
# 6400/8653 [=====================>........] - ETA: 15s - loss: 0.0876 - mean_squared_error: 0.0477Number of batchstart: 1
# 6656/8653 [======================>.......] - ETA: 14s - loss: 0.0871 - mean_squared_error: 0.0471Number of batchstart: 2
# 6912/8653 [======================>.......] - ETA: 12s - loss: 0.0869 - mean_squared_error: 0.0468Number of batchstart: 3
# 7168/8653 [=======================>......] - ETA: 10s - loss: 0.0868 - mean_squared_error: 0.0467Number of batchstart: 4
# 7424/8653 [========================>.....] - ETA: 8s - loss: 0.0857 - mean_squared_error: 0.0459 Number of batchstart: 5
# 7680/8653 [=========================>....] - ETA: 6s - loss: 0.0862 - mean_squared_error: 0.0464Number of batchstart: 6
# 7936/8653 [==========================>...] - ETA: 5s - loss: 0.0864 - mean_squared_error: 0.0466Number of batchstart: 7
# 8192/8653 [===========================>..] - ETA: 3s - loss: 0.0859 - mean_squared_error: 0.0462Number of batchstart: 8
# 8448/8653 [============================>.] - ETA: 1s - loss: 0.0862 - mean_squared_error: 0.0466Number of batchstart: 9
# 8653/8653 [==============================] - 61s - loss: 0.0860 - mean_squared_error: 0.0464

# %% [markdown]
# ## Optimization
# Congratulations! You've built a neural network with convolutions, pooling, dropout, and fully-connected layers, all in just a few lines of code.
#
# Have fun with the model and see how well you can do! Add more layers, or regularization, or different padding, or batches, or more training epochs.
#
# What is the best validation accuracy you can achieve?

# %%
# TODO: Build a model
preds = model.predict(X_train[1190:1310])
print("Pred = ", preds.T, "\nSteering angle = ", y_train[1190:1310])
# TODO: Compile and train the model

# %% [markdown]
# **Best Validation Accuracy:** (fill in here)

# %% [markdown]
# ## Testing
# Once you've picked out your best model, it's time to test it.
#
# Load up the test data and use the [`evaluate()` method](https://keras.io/models/model/#evaluate) to see how well it does.
#
# Hint 1: The `evaluate()` method should return an array of numbers. Use the [`metrics_names`](https://keras.io/models/model/) property to get the labels.

# %%
# TODO: Evaluate model on test data
# test_score = model.evaluate(X_normalized_test, y_one_hot_test)
val_score = model.evaluate(X_train, y_train)

print(val_score)

# %% [markdown]
# **Test Accuracy:** (84.37)

# %% [markdown]
# ## Save Model

# %%
from keras.models import load_model

model.save('model_user_trainigdata_generator_07.h5')  # creates a HDF5 file 'my_model.h5'
# del model  # deletes the existing model

# # returns a compiled model
# # identical to the previous one
# model = load_model('model_trial_allsampledata_02.h5')

# %% [markdown]
# ## Summary
# Keras is a great tool to use if you want to quickly build a neural network and evaluate performance.

# %% [markdown]
# ### Hello
#
# second
# third
